# %%
#make venns
import os
import shelve
from metaproteomics.file_processing import blazmass_tools
OUT = "/home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/out"
from metaproteomics.analysis import venn

# %%
# %matplotlib inline

# %%
sample = samples['RTsep_unenr1']

# %%
sample.__dict__.keys()
# Out:
# dict_keys(['dta_select', 'loci_pep_prot', 'db_info', 'peptides', 'pep_quant', 'prot_to_pep', 'prot_ids', 'sample_name'])

# %%
samples = shelve.open(os.path.join(OUT,"samples.shelve"))
sample_peptides = {name: blazmass_tools.get_unmod_peptides(sample.dta_select) for name,sample in samples.items()}

# %%
venn.make_vens(sample_peptides, ['RTsep_unenr1','RTsep_unenr2','RTsep_unenr3'], "peptides", normalized=False)
# Out:
# /home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/venv/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
venn.make_vens(sample_peptides, ['WTsep_unenr1','WTsep_unenr2','WTsep_unenr3'], "peptides", normalized=False)
# Out:
# /home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/venv/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
venn.make_vens(sample_peptides, ['Ragsep_unenr1','Ragsep_unenr2','Ragsep_unenr3'], "peptides", normalized=False)
# Out:
# /home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/venv/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
rag = ['Ragsep_unenr1','Ragsep_unenr2','Ragsep_unenr3']
rt = ['RTsep_unenr1','RTsep_unenr2','RTsep_unenr3']
wt = ['WTsep_unenr1','WTsep_unenr2','WTsep_unenr3']
venn.boolean_make_vens([rt, rag, wt], sample_peptides, "union")
# Out:
# /home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/venv/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
venn.boolean_make_vens([rt, rag, wt], sample_peptides, "intersection")
# Out:
# /home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/venv/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
