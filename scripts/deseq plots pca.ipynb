# %%
library("DESeq2")
library("geneplotter")
library("ggplot2")
library("vsn")
library("genefilter")
setwd("/home/gstupp/projects/Wolan/cmoon/CM7_CM1E2d56col_unenr123_rawextract_2017/")

# %%
load("out/dds_treatment")
rld <- rlog(dds)

# %%
sizeFactors(dds)
# Out:
#  RTsep_unenr1  RTsep_unenr2  RTsep_unenr3 Ragsep_unenr1 Ragsep_unenr2
#     1.1832430     0.9738534     1.2838946     0.9210959     0.9886745
# Ragsep_unenr3  WTsep_unenr1  WTsep_unenr2  WTsep_unenr3
#     1.0201713     1.0321839     1.0049706     1.1789412

# %%
meanSdPlot(assay(rld))
# Out:
# plot without title

# %%
rld$sample.type = c("RT","RT","RT","Rag","Rag","Rag","WT","WT","WT")

# %%
# WT=blue, Rag=green, and RT=red
data <- plotPCA(rld, intgroup=c("technical", "sample.type"), returnData=TRUE)
#data = data[c(1,2,3,7,8,9,4,5,6),]
percentVar <- round(100 * attr(data, "percentVar"))
ggplot(data, aes(PC1, PC2, shape=technical, color=sample.type, order=sample.type)) + 
scale_colour_manual(values = c("green", "red", "blue")) + 
geom_point(size=3) +  
xlab(paste0("PC1: ",percentVar[1],"% variance")) +
ylab(paste0("PC2: ",percentVar[2],"% variance"))
# Out:
# plot without title
